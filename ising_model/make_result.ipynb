# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("flips.csv")
print(df.columns)
# Out:
# Index([' MCS', ' m'], dtype='object')

# %%
plt.plot(df[' MCS'], df[' m'], "ro")

# %%
df = pd.read_csv("tmp.csv")
plt.plot(df[' MCS'], df[' m'], "ro")

# %%
df = pd.read_csv("tmp2.csv")
plt.plot(df[' MCS'], df[' m'], "bo")
