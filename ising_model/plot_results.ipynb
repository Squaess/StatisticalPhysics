# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.2.5
# ✔ tibble  2.1.1     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data1 <- read_csv("magnetization.csv")
data1 <- cbind(data1, L=25)

data10 <- read_csv("magnetization10.csv")
data25 <- read_csv("magnetization25.csv")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )

# %%
ggplot(data = data1, aes(T, m)) + geom_point() + ylim(0,1)
ggplot() + geom_point(data = data10, aes(T, m), color="red") + geom_point(data = data25, aes(T,m), color="blue") + ylim(0,1)
# Out:
# plot without title
# plot without title

# %%
flips.data <- read_csv("flips.csv")
ggplot(data = flips.data, aes(MCS, m)) + geom_point()
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp2.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp3.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title
