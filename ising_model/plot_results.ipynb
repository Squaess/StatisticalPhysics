# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.2.5
# ✔ tibble  2.1.1     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data1 <- read_csv("magnetization.csv")
data1 <- cbind(data1, L=25)

data10 <- read_csv("magnetization10.csv")
data25 <- read_csv("magnetization25.csv")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )

# %%
ggplot(data = data1, aes(T, m)) + geom_point() + ylim(0,1)
ggplot() + geom_point(data = data10, aes(T, m), color="red") + geom_point(data = data25, aes(T,m), color="blue") + ylim(0,1)
# Out:
# plot without title
# plot without title

# %%
data10.2 <- read_csv("mag10.csv")
ggplot(data = data10.2, aes(T, m)) + geom_point()
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# plot without title

# %%
flips.data <- read_csv("flips.csv")
ggplot(data = flips.data, aes(MCS, m)) + geom_point()
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
data.tmp <- read_csv("tmp2.csv")
ggplot() + geom_point(data = data.tmp, aes(MCS, m))
# Out:
# Parsed with column specification:
# cols(
#   MCS = col_integer(),
#   m = col_double()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice1-20.csv")
table1$m <- factor(table1$m)
ggplot() + 
geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice1-100.csv")
table1$m <- factor(table1$m)
ggplot() + geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("grey80", "#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice226-100.csv")
table1$m <- factor(table1$m)
ggplot() + geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("grey80", "#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice226-20.csv")
table1$m <- factor(table1$m)
ggplot() + geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("grey80", "#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice5-20.csv")
table1$m <- factor(table1$m)
ggplot() + geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("grey80", "#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
table1 <- read_csv("v2/lattice5-100.csv")
table1$m <- factor(table1$m)
ggplot() + geom_raster(data = table1, aes(x = x, y = y, fill=m)) + 
scale_fill_manual(values=c("grey80", "#B40404", "#0B6121", "#FFBF00"))
# Out:
# Parsed with column specification:
# cols(
#   x = col_integer(),
#   y = col_integer(),
#   m = col_integer()
# )
# plot without title

# %%
ggplot(faithfuld, aes(waiting, eruptions)) +
 geom_raster(aes(fill = density))
head(faithfuld,5)
# Out:
#   eruptions waiting density
# 1 1.600000  43      0.003216159
# 2 1.647297  43      0.003835375
# 3 1.694595  43      0.004435548
# 4 1.741892  43      0.004977614
# 5 1.789189  43      0.005424238
# plot without title

# %%
data.tmp <- read_csv("v2//flips.csv")
ggplot() + geom_point(data = data.tmp, aes(k, m))
# Out:
# Parsed with column specification:
# cols(
#   k = col_integer(),
#   m = col_double()
# )
# plot without title
