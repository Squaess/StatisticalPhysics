# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.5.3"-- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.0     v purrr   0.2.5
# v tibble  2.1.1     v dplyr   0.7.6
# v tidyr   0.8.1     v stringr 1.4.0
# v readr   1.1.1     v forcats 0.3.0
# Warning message:
# "package 'ggplot2' was built under R version 3.5.3"Warning message:
# "package 'tibble' was built under R version 3.5.3"Warning message:
# "package 'stringr' was built under R version 3.5.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
mag10 <- read_csv("mag10.csv")
mag50 <- read_csv("mag50.csv")
mag100 <- read_csv("mag100.csv")

ggplot() + geom_point(data = mag10, aes(T, m)) +
geom_point(data = mag50, aes(T, m), color="red") +
geom_point(data = mag100, aes(T, m), color="green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# plot without title

# %%
fin10 <- read_csv("finite10.csv")
ggplot() + 
geom_point(data = mag10, aes(log((abs(T - 2.269)/2.269 ) * L), log(m * L**(1/8)))) +
geom_point(data = mag50, aes(log((abs(T - 2.269)/2.269 ) * L), log(m * L**(1/8))), color="red") + 
geom_point(data = mag100, aes(log((abs(T - 2.269)/2.269 ) * L), log(m * L**(1/8))), color="green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# plot without title

# %%
energ10 <- read_csv("ener10.csv")
energ50 <- read_csv("ener50.csv")
energ100 <- read_csv("ener100.csv")

head(energ10, 5)
ggplot() + geom_point(data = energ10, aes(T, e)) +
geom_point(data = energ50, aes(T, e), color = "red") + 
geom_point(data = energ100, aes(T, e), color = "green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
#   T    e         L
# 1 1.54 -1.944547 10
# 2 1.58 -1.932082 10
# 3 1.62 -1.924001 10
# 4 1.66 -1.909352 10
# 5 1.70 -1.896257 10
# plot without title

# %%
sus10 <- read_csv("sus10.csv")
sus50 <- read_csv("sus50.csv")
sus100 <- read_csv("sus100.csv")

ggplot() + geom_point(data = sus10, aes(T, m)) + 
geom_point(data = sus50, aes(T, m), color="red") +
geom_point(data = sus100, aes(T, m), color="green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   m = col_double(),
#   L = col_integer()
# )
# plot without title

# %%
heat10 <- read_csv("heat10.csv")
heat50 <- read_csv("heat50.csv")
heat100 <- read_csv("heat100.csv")

ggplot() + geom_point(data = heat10, aes(T, e)) +
geom_point(data = heat50, aes(T, e), color="red") + 
geom_point(data = heat100, aes(T, e), color="green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double(),
#   L = col_integer()
# )
# plot without title

# %%
ggsave("todelete.png")
# Out:
# Saving 6.67 x 6.67 in image

# %%
bind10 <- read_csv("binder10.csv")
bind50 <- read_csv("binder50.csv")
bind100 <- read_csv("binder100.csv")

ggplot() + geom_point(data = bind10, aes(T, b)) + 
geom_point(data = bind50, aes(T, b), color="red") + 
geom_point(data = bind100, aes(T, b), color="green")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   b = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   b = col_double(),
#   L = col_integer()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   b = col_double(),
#   L = col_integer()
# )
# plot without title
