# %%
library(tidyverse)

# %%
data <- read_csv("result.csv")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   S = col_double(),
#   S2 = col_double()
# )

# %%
head(data, 5)
# Out:
#   T    S         S2
# 1 0.03 0.6542336 0.9894642
# 2 0.06 0.8351021 0.9788600
# 3 0.09 0.6277460 0.9680194
# 4 0.12 0.5279109 0.9569583
# 5 0.15 0.6904805 0.9463701

# %%
ggplot() + geom_point(data = data, aes(T, S), color="red") + geom_point(data = data, aes(T, S2), color="blue")
# Out:
# plot without title
