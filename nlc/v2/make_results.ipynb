# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.2.5
# ✔ tibble  2.1.1     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data <- read_csv("result.csv")
data2 <- read_csv("result3.csv")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   S = col_double(),
#   S2 = col_double()
# )
# Parsed with column specification:
# cols(
#   T = col_double(),
#   S = col_double(),
#   S2 = col_double()
# )

# %%
head(data, 5)
tail(data, 5)
# Out:
#   T          S         S2
# 1 0.01750000 0.4711147 0.9938678
# 2 0.03500000 0.7773887 0.9876900
# 3 0.05250000 0.3981161 0.9814321
# 4 0.06999999 0.6264807 0.9752752
# 5 0.08749999 0.1037572 0.9689576
#   T     S           S2
# 1 1.440 0.005336042 0.09546928
# 2 1.455 0.003412402 0.09256311
# 3 1.470 0.007847353 0.09022212
# 4 1.485 0.005914769 0.09247932
# 5 1.500 0.006167530 0.08931929

# %%
# ggplot() + geom_point(data = data, aes(T, S), color="red") + geom_point(data = data, aes(T, S2), color="blue") +
ggplot() + geom_point(data = data, aes(T, S2), color="blue") +
ylab("S") +
geom_hline(aes(yintercept=0.4, linetype = "0.4"), color="red") +
geom_vline(aes(xintercept=0.835, linetype = "0.835"), color="green") +
scale_linetype_manual(name = "line", values=c(2,2),
                      guide = guide_legend(override.aes = list(color = c("red", "green")))) +
geom_text(aes(0,0.4,label = 0.4, vjust = -1))+
geom_text(aes(0.835,0,label = 0.835, hjust = -0.5))
# Out:
# plot without title

# %%
data2$S[2] <- data2$S[2] + 0.01

# %%
ggplot() + geom_point(data = data2, aes(T, S2), color="blue") +
# geom_point(data = data2, aes(T, S), color="green") +
# geom_line(data = data2, aes(T, S), color="green") +
geom_hline(aes(yintercept=0.4, linetype = "0.4"), color="red") +
geom_vline(aes(xintercept=0.835, linetype = "0.835"), color="green") +
ylab("S")
# Out:
# plot without title

# %%
ggsave("plot3.png", width=7, height=5)

# %%
ggplot() + geom_hline(yintercept=0.4, linetype="dashed", color = "red")
# Out:
# plot without title
