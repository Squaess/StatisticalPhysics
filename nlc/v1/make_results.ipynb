# %%
library(tidyverse)

# %%
data <- read_csv("result.csv")
# Out:
# Parsed with column specification:
# cols(
#   T = col_double(),
#   e = col_double()
# )

# %%
head(data, 5)
# Out:
#   T     e
# 1 0.025 0.8574781
# 2 0.050 0.8915088
# 3 0.075 0.7968529
# 4 0.100 0.8688368
# 5 0.125 0.6559950

# %%
ggplot() + geom_point(data = data, aes(T, e))
# Out:
# plot without title
